# %%
#%matplotlib inline

import numpy as np
import pandas as pd
import os

# %%
unitsTab=pd.read_csv('codes/units.csv')
unitsTab.index = unitsTab['Unit Code']
unitsDict=unitsTab.to_dict()["Units"]

# %%
paramsTab=pd.read_csv('codes/parameters.csv')
paramsTab.index = paramsTab['Parameter Code']
paramsDict = paramsTab.to_dict()['Parameter']

# %%
def loadData(path):
    df=pd.read_csv(path, parse_dates=[3])
    df.dropna(subset=['datetime'], inplace=True)
    
    df.index = df.datetime
    df.sort_index(inplace=True)

    df['unitCode']=df.unit
    df['parameterCode']=df.parameter

    df.replace({'unit':unitsDict, 'parameter':paramsDict}, inplace=True)
    
    return df

# %%
basePath='raw_data/Harrisburg data/'
files=os.listdir(basePath)
file=basePath+files[0]
print(files)
# Out:
# ['AQDM_2142402333 (1).txt', 'AQDM_2142473032 (1).txt', 'AQDM_2143508020.txt', 'AQDM_2143639022.txt', 'AQDM_2143621601.txt', 'AQDM_2142175470 (2).txt', 'AQDM_2142473032.txt', 'AQDM_2142175470 (3).txt', 'AQDM_2142175470 (4).txt', 'AQDM_2142091599.txt', 'AQDM_2142175470 (1).txt', 'AQDM_2142402333.txt', 'AQDM_2141990090.txt', 'AQDM_2141990090 (1).txt', 'AQDM_2142175470.txt']

# %%
df1=loadData(file)
df1.head(2)
# Out:
#                              site  data_status  action_code  \
# datetime
# 2013-01-01 07:00:00  840481410044          1.0         10.0
# 2013-01-01 08:00:00  840481410044          1.0         10.0
#
#                                datetime                 parameter  duration  \
# datetime
# 2013-01-01 07:00:00 2013-01-01 07:00:00  PM2.5 - Local Conditions      60.0
# 2013-01-01 08:00:00 2013-01-01 08:00:00  PM2.5 - Local Conditions      60.0
#
#                      frequency  value                         unit   qc  \
# datetime
# 2013-01-01 07:00:00        0.0    1.0  Micrograms/cubic meter (LC)  0.0
# 2013-01-01 08:00:00        0.0    2.0  Micrograms/cubic meter (LC)  0.0
#
#                          ...              lon  GISDatum    elev method_code  \
# datetime                 ...
# 2013-01-01 07:00:00      ...      -106.455227     WGS84  1122.0       170.0
# 2013-01-01 08:00:00      ...      -106.455227     WGS84  1122.0       170.0
#
#                      mpc  mpc_value  uncertainty  qualifiers  unitCode  \
# datetime
# 2013-01-01 07:00:00  1.0        5.0          NaN         NaN     105.0
# 2013-01-01 08:00:00  1.0        5.0          NaN         NaN     105.0
#
#                     parameterCode
# datetime
# 2013-01-01 07:00:00       88101.0
# 2013-01-01 08:00:00       88101.0
#
# [2 rows x 22 columns]

# %%
df1.describe()
# Out:
#         data_status  action_code  duration  frequency         value       qc  \
# count  30242.000000      30242.0   30242.0    30242.0  30242.000000  30242.0
# mean       0.477945         10.0      60.0        0.0     10.017175      0.0
# std        0.499522          0.0       0.0        0.0     12.753068      0.0
# min        0.000000         10.0      60.0        0.0     -9.100000      0.0
# 25%        0.000000         10.0      60.0        0.0      4.000000      0.0
# 50%        0.000000         10.0      60.0        0.0      7.000000      0.0
# 75%        1.000000         10.0      60.0        0.0     12.000000      0.0
# max        1.000000         10.0      60.0        0.0    485.000000      0.0
#
#            poc           lat           lon     elev  method_code      mpc  \
# count  30242.0  3.024200e+04  3.024200e+04  30242.0      30242.0  30242.0
# mean       6.0  3.176569e+01 -1.064552e+02   1122.0        170.0      1.0
# std        0.0  7.105545e-15  2.842218e-14      0.0          0.0      0.0
# min        6.0  3.176568e+01 -1.064552e+02   1122.0        170.0      1.0
# 25%        6.0  3.176568e+01 -1.064552e+02   1122.0        170.0      1.0
# 50%        6.0  3.176568e+01 -1.064552e+02   1122.0        170.0      1.0
# 75%        6.0  3.176568e+01 -1.064552e+02   1122.0        170.0      1.0
# max        6.0  3.176568e+01 -1.064552e+02   1122.0        170.0      1.0
#
#        mpc_value  uncertainty  unitCode  parameterCode
# count    30242.0          0.0   30242.0        30242.0
# mean         5.0          NaN     105.0        88101.0
# std          0.0          NaN       0.0            0.0
# min          5.0          NaN     105.0        88101.0
# 25%          5.0          NaN     105.0        88101.0
# 50%          5.0          NaN     105.0        88101.0
# 75%          5.0          NaN     105.0        88101.0
# max          5.0          NaN     105.0        88101.0

# %%
print(df1.parameter.unique())
# Out:
# ['PM2.5 - Local Conditions']

# %%
# for f in files:
#     df = loadData(basePath+f)
#     print(f, '\t', df.index.min(), df.index.max(), df.parameter.unique(), df.unit.unique())

# %%
filesFrame=pd.DataFrame(files, columns=['filename'])
filesFrame.head()
# Out:
#                   filename
# 0  AQDM_2142402333 (1).txt
# 1  AQDM_2142473032 (1).txt
# 2      AQDM_2143508020.txt
# 3      AQDM_2143639022.txt
# 4      AQDM_2143621601.txt

# %%
filesFrame['table'] = [loadData(basePath+f) for f in filesFrame.filename]
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2910: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
filesFrame
# Out:
#                    filename                                              table
# 0   AQDM_2142402333 (1).txt                               site  data_status...
# 1   AQDM_2142473032 (1).txt                               site  data_status...
# 2       AQDM_2143508020.txt                               site  data_status...
# 3       AQDM_2143639022.txt  Empty DataFrame
# Columns: [site, data_status, a...
# 4       AQDM_2143621601.txt  Empty DataFrame
# Columns: [site, data_status, a...
# 5   AQDM_2142175470 (2).txt                               site  data_status...
# 6       AQDM_2142473032.txt                               site  data_status...
# 7   AQDM_2142175470 (3).txt                               site  data_status...
# 8   AQDM_2142175470 (4).txt                               site  data_status...
# 9       AQDM_2142091599.txt                               site  data_status...
# 10  AQDM_2142175470 (1).txt                               site  data_status...
# 11      AQDM_2142402333.txt                               site  data_status...
# 12      AQDM_2141990090.txt                               site  data_status...
# 13  AQDM_2141990090 (1).txt                               site  data_status...
# 14      AQDM_2142175470.txt                               site  data_status...

# %%
allData=pd.concat(list(filesFrame.table))
allData.sort_index(inplace=True)
allData.drop_duplicates(['datetime','value','parameter','unit'], inplace=True)
allData.tail(10)
# Out:
#                              site  data_status  action_code  \
# datetime
# 2017-01-01 04:00:00  840420430401          0.0         10.0
# 2017-01-01 04:00:00  840481410044          0.0         10.0
# 2017-01-01 04:00:00  840481410044          0.0         10.0
# 2017-01-01 05:00:00  840481410044          0.0         10.0
# 2017-01-01 05:00:00  840481410044          0.0         10.0
# 2017-01-01 05:00:00  840481130069          0.0         10.0
# 2017-01-01 05:00:00  840482010416          0.0         10.0
# 2017-01-01 05:00:00  840482010416          0.0         10.0
# 2017-01-01 06:00:00  840481410044          0.0         10.0
# 2017-01-01 06:00:00  840481410044          0.0         10.0
#
#                                datetime                 parameter  duration  \
# datetime
# 2017-01-01 04:00:00 2017-01-01 04:00:00                     Ozone      60.0
# 2017-01-01 04:00:00 2017-01-01 04:00:00  PM2.5 - Local Conditions      60.0
# 2017-01-01 04:00:00 2017-01-01 04:00:00       Wind Speed - Scalar      60.0
# 2017-01-01 05:00:00 2017-01-01 05:00:00  PM2.5 - Local Conditions      60.0
# 2017-01-01 05:00:00 2017-01-01 05:00:00       Wind Speed - Scalar      60.0
# 2017-01-01 05:00:00 2017-01-01 05:00:00           Carbon monoxide      60.0
# 2017-01-01 05:00:00 2017-01-01 05:00:00                     Ozone      60.0
# 2017-01-01 05:00:00 2017-01-01 05:00:00       Outdoor Temperature      60.0
# 2017-01-01 06:00:00 2017-01-01 06:00:00  PM2.5 - Local Conditions      60.0
# 2017-01-01 06:00:00 2017-01-01 06:00:00       Wind Speed - Scalar      60.0
#
#                      frequency   value                         unit   qc  \
# datetime
# 2017-01-01 04:00:00        0.0   0.030            Parts per million  0.0
# 2017-01-01 04:00:00        0.0   3.900  Micrograms/cubic meter (LC)  0.0
# 2017-01-01 04:00:00        0.0   5.500                        Knots  0.0
# 2017-01-01 05:00:00        0.0  18.900  Micrograms/cubic meter (LC)  0.0
# 2017-01-01 05:00:00        0.0   6.400                        Knots  0.0
# 2017-01-01 05:00:00        0.0   0.229            Parts per million  0.0
# 2017-01-01 05:00:00        0.0   0.014            Parts per million  0.0
# 2017-01-01 05:00:00        0.0  66.000           Degrees Fahrenheit  0.0
# 2017-01-01 06:00:00        0.0   4.900  Micrograms/cubic meter (LC)  0.0
# 2017-01-01 06:00:00        0.0   7.000                        Knots  0.0
#
#                          ...              lon  GISDatum    elev method_code  \
# datetime                 ...
# 2017-01-01 04:00:00      ...       -76.846988     WGS84   125.0        87.0
# 2017-01-01 04:00:00      ...      -106.455227     WGS84  1122.0       170.0
# 2017-01-01 04:00:00      ...      -106.455227     WGS84  1122.0        50.0
# 2017-01-01 05:00:00      ...      -106.455227     WGS84  1122.0       170.0
# 2017-01-01 05:00:00      ...      -106.455227     WGS84  1122.0        50.0
# 2017-01-01 05:00:00      ...       -96.860117     WGS84   127.0       593.0
# 2017-01-01 05:00:00      ...       -95.294722     WGS84    10.0        47.0
# 2017-01-01 05:00:00      ...       -95.294722     WGS84    10.0        40.0
# 2017-01-01 06:00:00      ...      -106.455227     WGS84  1122.0       170.0
# 2017-01-01 06:00:00      ...      -106.455227     WGS84  1122.0        50.0
#
#                      mpc  mpc_value  uncertainty  qualifiers  unitCode  \
# datetime
# 2017-01-01 04:00:00  1.0      0.005          NaN         NaN       7.0
# 2017-01-01 04:00:00  1.0      5.000          NaN         NaN     105.0
# 2017-01-01 04:00:00  1.0      0.600          NaN         NaN      13.0
# 2017-01-01 05:00:00  1.0      5.000          NaN         NaN     105.0
# 2017-01-01 05:00:00  1.0      0.600          NaN         NaN      13.0
# 2017-01-01 05:00:00  1.0      0.020          NaN         NaN       7.0
# 2017-01-01 05:00:00  1.0      0.005          NaN         NaN       7.0
# 2017-01-01 05:00:00  1.0    -60.000          NaN         NaN      15.0
# 2017-01-01 06:00:00  1.0      5.000          NaN         NaN     105.0
# 2017-01-01 06:00:00  1.0      0.600          NaN         NaN      13.0
#
#                     parameterCode
# datetime
# 2017-01-01 04:00:00       44201.0
# 2017-01-01 04:00:00       88101.0
# 2017-01-01 04:00:00       61101.0
# 2017-01-01 05:00:00       88101.0
# 2017-01-01 05:00:00       61101.0
# 2017-01-01 05:00:00       42101.0
# 2017-01-01 05:00:00       44201.0
# 2017-01-01 05:00:00       62101.0
# 2017-01-01 06:00:00       88101.0
# 2017-01-01 06:00:00       61101.0
#
# [10 rows x 22 columns]

# %%
print(allData.parameter.unique())
# Out:
# ['Carbon monoxide' 'Ozone' 'PM2.5 - Local Conditions' 'Wind Speed - Scalar'
#  'Outdoor Temperature']

# %%
allData[allData.parameter=='Ozone'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-5a0aa671267c> in <module>()
# ----> 1 allData[allData.parameter=='Ozone'].plot()
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1690                             pass
#    1691                 data = series
# -> 1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
#    1694     plot_obj.generate()
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in __init__(self, data, **kwargs)
#     902
#     903     def __init__(self, data, **kwargs):
# --> 904         MPLPlot.__init__(self, data, **kwargs)
#     905         if self.stacked:
#     906             self.data = self.data.fillna(value=0)
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#     134
#     135         if grid is None:
# --> 136             grid = False if secondary_y else self.plt.rcParams['axes.grid']
#     137
#     138         self.grid = grid
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas/_libs/lib.c:44594)()
#
# /usr/local/lib/python3.5/dist-packages/pandas/plotting/_core.py in plt(self)
#     514     @cache_readonly
#     515     def plt(self):
# --> 516         import matplotlib.pyplot as plt
#     517         return plt
#     518
#
# ImportError: No module named 'matplotlib'
